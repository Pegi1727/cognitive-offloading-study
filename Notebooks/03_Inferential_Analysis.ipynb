# %% [markdown]
# # Inferential Statistics: ANOVA
# Analyzing variance across groups.

# %%
d <- read.csv('screening_data.csv')
d$Group_Note <- as.factor(d$Group_Note)
model <- aov(Total ~ Group_Note, data=d)
summary(model)
